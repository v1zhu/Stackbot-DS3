# %% [markdown]
# ## Answer Ranking Function

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display

# %%
df = pd.read_csv('data/cleaned.csv')

# %%
df.head()
# Out:
#     Id                                      Tag  Score_question  \
# 0  469  ['python', 'osx', 'fonts', 'photoshop']              21
# 1  469  ['python', 'osx', 'fonts', 'photoshop']              21
# 2  469  ['python', 'osx', 'fonts', 'photoshop']              21
# 3  469  ['python', 'osx', 'fonts', 'photoshop']              21
# 4  502    ['python', 'windows', 'image', 'pdf']              27
#
#                                   Title  \
# 0  find full path font display name mac
# 1  find full path font display name mac
# 2  find full path font display name mac
# 3  find full path font display name mac
# 4           get preview jpeg pdf window
#
#                                        Body_question  Score_answer  \
# 0  using photoshop javascript api find font given...             4
# 1  using photoshop javascript api find font given...             2
# 2  using photoshop javascript api find font given...            12
# 3  using photoshop javascript api find font given...             1
# 4  python application need generate jpeg preview ...             9
#
#                                          Body_answer
# 0  open terminal terminal type locate insertfonth...
# 1  not able find anything directly think iterate ...
# 2  unfortunately api not deprecated located appli...
# 3  must method cocoa get list font would use pyob...
# 4  use imagemagick convert utility see example ht...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987122 entries, 0 to 987121
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Id              987122 non-null  int64
#  1   Tag             987122 non-null  object
#  2   Score_question  987122 non-null  int64
#  3   Title           986547 non-null  object
#  4   Body_question   987101 non-null  object
#  5   Score_answer    987122 non-null  int64
#  6   Body_answer     986275 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 52.7+ MB

# %%
df.describe()
# Out:
#                  Id  Score_question   Score_answer
# count  9.871220e+05   987122.000000  987122.000000
# mean   2.053496e+07        7.275413       3.028437
# std    1.195486e+07       63.667863      21.263246
# min    4.690000e+02      -44.000000     -38.000000
# 25%    9.968532e+06        0.000000       0.000000
# 50%    2.103550e+07        1.000000       1.000000
# 75%    3.115233e+07        3.000000       3.000000
# max    4.014319e+07     5524.000000    8384.000000

# %%
df_SortedByQuestionScore = df.sort_values(by="Score_question", ascending=False)

# %%
df_SortedByQuestionScore.head()
# Out:
#           Id                                                Tag  \
# 5863  231767  ['python', 'iterator', 'generator', 'yield', '...
# 5872  231767  ['python', 'iterator', 'generator', 'yield', '...
# 5870  231767  ['python', 'iterator', 'generator', 'yield', '...
# 5869  231767  ['python', 'iterator', 'generator', 'yield', '...
# 5868  231767  ['python', 'iterator', 'generator', 'yield', '...
#
#       Score_question          Title  \
# 5863            5524  yield keyword
# 5872            5524  yield keyword
# 5870            5524  yield keyword
# 5869            5524  yield keyword
# 5868            5524  yield keyword
#
#                                           Body_question  Score_answer  \
# 5863  use yield keyword python example trying unders...            24
# 5872  use yield keyword python example trying unders...             1
# 5870  use yield keyword python example trying unders...             8
# 5869  use yield keyword python example trying unders...            27
# 5868  use yield keyword python example trying unders...            14
#
#                                             Body_answer
# 5863  like every answer suggests yield used creating...
# 5872  summary yield statement transforms function fa...
# 5870  yet another tl dr iterator list next return ne...
# 5869  tl dr find building list scratch def n x range...
# 5868  answer speaks perspective using python generat...

# %%
df_SortedByAnswerScore = df.sort_values(by="Score_answer", ascending=False)

# %%
df_SortedByAnswerScore.head()
# Out:
#            Id                                                Tag  \
# 5845   231767  ['python', 'iterator', 'generator', 'yield', '...
# 2233   100003  ['python', 'oop', 'metaclass', 'python-datamod...
# 20287  739654       ['python', 'decorator', 'python-decorators']
# 10416  394809  ['python', 'operators', 'ternary-operator', 'c...
# 14187  522563                        ['python', 'loops', 'list']
#
#        Score_question                                 Title  \
# 5845             5524                         yield keyword
# 2233             3219                      metaclass python
# 20287            1920  make chain function decorator python
# 10416            2655   python ternary conditional operator
# 14187            1512           accessing index python loop
#
#                                            Body_question  Score_answer  \
# 5845   use yield keyword python example trying unders...          8384
# 2233                                     metaclasses use          4510
# 20287  make two decorator python would following make...          3332
# 10416  python not ternary conditional operator possib...          3110
# 14187  access index list like following ints loop usi...          2666
#
#                                              Body_answer
# 5845   understand yield must understand generator gen...
# 2233   class object understanding metaclasses need ma...
# 20287  not long explanation see paolo answer decorato...
# 10416  yes added version syntax condition else b firs...
# 14187  using additional state variable index variable...

# %%
best_questions_overall = (df.drop_duplicates(subset="Id").sort_values(by="Score_question", ascending=False))

# %%
best_questions_overall.head()
# Out:
#            Id                                                Tag  \
# 5842   231767  ['python', 'iterator', 'generator', 'yield', '...
# 2228   100003  ['python', 'oop', 'metaclass', 'python-datamod...
# 1899    82831                  ['python', 'file', 'filesystems']
# 10416  394809  ['python', 'operators', 'ternary-operator', 'c...
# 2035    89228  ['python', 'shell', 'command', 'subprocess', '...
#
#        Score_question                                   Title  \
# 5842             5524                           yield keyword
# 2228             3219                        metaclass python
# 1899             2729  check whether file exists using python
# 10416            2655     python ternary conditional operator
# 2035             2312         calling external command python
#
#                                            Body_question  Score_answer  \
# 5842   use yield keyword python example trying unders...           141
# 2228                                     metaclasses use           217
# 1899   check whether file exists without using try st...           211
# 10416  python not ternary conditional operator possib...          3110
# 2035   call external command would typed unix shell w...            27
#
#                                              Body_answer
# 5842   yield like return return whatever tell differe...
# 2228   metaclasses secret sauce make work default met...
# 1899                                     import filename
# 10416  yes added version syntax condition else b firs...
# 2035   import o command note dangerous since command ...

# %%
best_answers_overall = (df.drop_duplicates(subset="Id").sort_values(by="Score_answer", ascending=False))

# %%
best_answers_overall.head()
# Out:
#            Id                                                Tag  \
# 10416  394809  ['python', 'operators', 'ternary-operator', 'c...
# 1162    53513                                 ['python', 'list']
# 20283  739654       ['python', 'decorator', 'python-decorators']
# 13769  509211                        ['python', 'list', 'slice']
# 4445   176918                                 ['python', 'list']
#
#        Score_question                                            Title  \
# 10416            2655              python ternary conditional operator
# 1162             1615                        best way check list empty
# 20283            1920             make chain function decorator python
# 13769            1331                    explain python slice notation
# 4445             1222  finding index item given list containing python
#
#                                            Body_question  Score_answer  \
# 10416  python not ternary conditional operator possib...          3110
# 1162            example passed following check see empty          2388
# 20283  make two decorator python would following make...          2338
# 13769  need good explanation reference plus python sl...          1891
# 4445   list foo bar baz item list bar cleanest way ge...          1857
#
#                                              Body_answer
# 10416  yes added version syntax condition else b firs...
# 1162   not print list empty using implicit booleannes...
# 20283  check documentation see decorator work asked d...
# 13769  pretty simple really start end item start star...
# 4445       foo bar baz bar reference data structure list

# %%
Raw_Question_Scores_Sorted = df[["Id","Score_question", "Score_answer"]].sort_values(by="Score_question", ascending=True)

# %%
Raw_Answer_Scores_Sorted = df[["Id","Score_question", "Score_answer"]].sort_values(by="Score_answer", ascending=True)

# %%
Raw_Question_Scores_Sorted
# Out:
#               Id  Score_question  Score_answer
# 608231  25970488             -44             4
# 608232  25970488             -44           -26
# 608234  25970488             -44            -1
# 608233  25970488             -44             4
# 720346  30402552             -32            10
# ...          ...             ...           ...
# 5842      231767            5524           141
# 5843      231767            5524            78
# 5844      231767            5524           236
# 5861      231767            5524            24
# 5854      231767            5524            51
#
# [987122 rows x 3 columns]

# %%
Raw_Question_Scores_Sorted.head(20)
# Out:
#               Id  Score_question  Score_answer
# 608231  25970488             -44             4
# 608232  25970488             -44           -26
# 608234  25970488             -44            -1
# 608233  25970488             -44             4
# 720346  30402552             -32            10
# 943609  38567618             -19             3
# 625523  26724585             -18             2
# 768071  32191198             -18             1
# 797706  33287341             -17            -1
# 867675  35779178             -17             1
# 867676  35779178             -17             0
# 797707  33287341             -17             0
# 797708  33287341             -17            -2
# 867674  35779178             -17             3
# 931027  38106947             -16             0
# 931029  38106947             -16             7
# 931028  38106947             -16             1
# 923712  37833625             -14             1
# 923711  37833625             -14             1
# 923713  37833625             -14             0

# %%
Raw_Answer_Scores_Sorted
# Out:
#               Id  Score_question  Score_answer
# 120465   4320679             105           -38
# 608232  25970488             -44           -26
# 77625    2725852              42           -24
# 12740     473620             185           -23
# 105956   3780737              11           -23
# ...          ...             ...           ...
# 14187     522563            1512          2666
# 10416     394809            2655          3110
# 20287     739654            1920          3332
# 2233      100003            3219          4510
# 5845      231767            5524          8384
#
# [987122 rows x 3 columns]

# %%
Raw_Answer_Scores_Sorted.head(20)
# Out:
#               Id  Score_question  Score_answer
# 120465   4320679             105           -38
# 608232  25970488             -44           -26
# 77625    2725852              42           -24
# 12740     473620             185           -23
# 105956   3780737              11           -23
# 22170     805066             271           -19
# 445        28796              52           -18
# 75802    2654149              17           -17
# 18941     688245              17           -17
# 39035    1408940              16           -16
# 113229   4042452              92           -15
# 4619      183042              26           -15
# 1681       72852             309           -14
# 4273      170337              49           -14
# 230681   9252543             157           -14
# 31355    1120148              30           -14
# 131312   4757178              57           -14
# 351033  14726789              22           -13
# 9994      379906            1130           -12
# 7156      279237             555           -12

# %%
Raw_Question_Scores_Sorted.head(20)
# Out:
#               Id  Score_question  Score_answer
# 608231  25970488             -44             4
# 720346  30402552             -32            10
# 943609  38567618             -19             3
# 625523  26724585             -18             2
# 768071  32191198             -18             1
# 797706  33287341             -17            -1
# 867675  35779178             -17             1
# 931027  38106947             -16             0
# 923712  37833625             -14             1

# %%
Raw_Answer_Scores_Sorted.head(20)
# Out:
#               Id  Score_question  Score_answer
# 120465   4320679             105           -38
# 608232  25970488             -44           -26
# 77625    2725852              42           -24
# 12740     473620             185           -23
# 105956   3780737              11           -23
# 22170     805066             271           -19
# 445        28796              52           -18
# 75802    2654149              17           -17
# 18941     688245              17           -17
# 39035    1408940              16           -16
# 113229   4042452              92           -15
# 4619      183042              26           -15
# 1681       72852             309           -14
# 4273      170337              49           -14
# 230681   9252543             157           -14
# 31355    1120148              30           -14
# 131312   4757178              57           -14
# 351033  14726789              22           -13
# 9994      379906            1130           -12
# 7156      279237             555           -12

# %%
plt.figure(figsize=(12,8))
plt.scatter(Raw_Answer_Scores_Sorted["Score_question"], Raw_Answer_Scores_Sorted["Score_answer"], alpha=0.6)
plt.xlabel("Question Score")
plt.ylabel("Answer Score")
plt.title("Question vs Answer Scores")
# Out:
# Text(0.5, 1.0, 'Question vs Answer Scores')

# %% [markdown]
# The above code sorts the Data and taking a closer look at the unique values/upvotes provided by the dataset. I've named these pretty intuitively so as to avoid any confusion as to what they refer to. My purpose behind doing this was to better understand which examples we would utilize/emphasize as good examples, and which would we de-emphasize as bad ones. I also ended up graphing this data to see if any interesting relationships would pop up. Another bonus of graphing the data is we can see any clear clusters. In this particular graph (above), the independent variable is shown to be the Question Score, and the dependent the Answer Score, as my core assumption was that the answer's scores would be dependent on the how good quality the question was. The next steps (assuming we do continue with this dataset, and in my opinion we should as it seems to be the most authoritative) would be to cluster the data (with linear/radial sections) and go from there determining which regions should again be weighted more versus less in our model.

# %%
df["Score_ratio"] = abs(df["Score_question"]).div(df["Score_answer"].replace(0, np.nan))

# %%
Raw_Scores_Ratios_Sorted = df[["Id","Body_question","Body_answer","Score_question","Score_answer","Score_ratio"]].sort_values(by="Score_ratio", ascending=False)

# %%
Raw_Scores_Ratios_Sorted.head(50)
# Out:
#              Id                                      Body_question  \
# 5872     231767  use yield keyword python example trying unders...
# 1929      82831  check whether file exists without using try st...
# 1931      82831  check whether file exists without using try st...
# 2062      89228  call external command would typed unix shell w...
# 2073      89228  call external command would typed unix shell w...
# 2071      89228  call external command would typed unix shell w...
# 2068      89228  call external command would typed unix shell w...
# 20290    739654  make two decorator python would following make...
# 20294    739654  make two decorator python would following make...
# 760       38987  two python dictionary want write single expres...
# 762       38987  two python dictionary want write single expres...
# 768       38987  two python dictionary want write single expres...
# 770       38987  two python dictionary want write single expres...
# 771       38987  two python dictionary want write single expres...
# 756       38987  two python dictionary want write single expres...
# 752       38987  two python dictionary want write single expres...
# 16757    613183  dictionary value read two field database strin...
# 16740    613183  dictionary value read two field database strin...
# 131148  4750806  pip replacement install pip using window bette...
# 131147  4750806  pip replacement install pip using window bette...
# 131143  4750806  pip replacement install pip using window bette...
# 131140  4750806  pip replacement install pip using window bette...
# 131137  4750806  pip replacement install pip using window bette...
# 131133  4750806  pip replacement install pip using window bette...
# 131139  4750806  pip replacement install pip using window bette...
# 3390     136097  difference function decorated staticmethod one...
# 6423     252703               difference list method append extend
# 14195    522563  access index list like following ints loop usi...
# 27453    986006  python documentation seems unclear whether par...
# 5871     231767  use yield keyword python example trying unders...
# 1933      82831  check whether file exists without using try st...
# 1934      82831  check whether file exists without using try st...
# 1915      82831  check whether file exists without using try st...
# 39822   1436703                                  difference python
# 39819   1436703                                  difference python
# 2310     101754  working version platform nice python api howev...
# 10429    394809  python not ternary conditional operator possib...
# 28610   1024847  possible add key python dictionary created not...
# 2061      89228  call external command would typed unix shell w...
# 2065      89228  call external command would typed unix shell w...
# 644       36932  mainly c developer currently working project p...
# 659       36932  mainly c developer currently working project p...
# 639       36932  mainly c developer currently working project p...
# 648       36932  mainly c developer currently working project p...
# 647       36932  mainly c developer currently working project p...
# 661       36932  mainly c developer currently working project p...
# 657       36932  mainly c developer currently working project p...
# 7435     287871  output colored text terminal python best unico...
# 1604      68645  possible static class variable method python s...
# 1602      68645  possible static class variable method python s...
#
#                                               Body_answer  Score_question  \
# 5872    summary yield statement transforms function fa...            5524
# 1929    demo try open fp pas except ioerror e print un...            2729
# 1931    import o iffile filename return success iffile...            2729
# 2062    use subprocess import call using list call ech...            2312
# 2073    import subprocess p df print give nice output ...            2312
# 2071    would recommend following method help u gettin...            2312
# 2068    using popen function subprocess python module ...            2312
# 20290   speaking counter example given counter shared ...            1920
# 20294   def makehtmltag tag args kwds def fn kwds kwds...            1920
# 760     solution not specified man love python z x not...            1867
# 762     union op two dictionary would something like b...            1867
# 768     collection import counter b c result dict coun...            1867
# 770     simpler solution not averse importing standard...            1867
# 771     know not really fit specific question one line...            1867
# 756     creates intermediary dict mean total number co...            1867
# 752     using dict comprehension may x b c dc xi x xi ...            1867
# 16757   python builtin dict ordered good news op origi...            1837
# 16740           using python x b c sorted print list list            1837
# 131148  get file search google copy save locally c dri...            1662
# 131147  pip already installed using python python bina...            1662
# 131143                                  download http run            1662
# 131140  install pip download install activepython open...            1662
# 131137  working feb tried installing pip window instal...            1662
# 131133  simple step wget http step wget http step pyth...            1662
# 131139  alternatively get installer pip virtualenv win...            1662
# 3390    another consideration respect staticmethod v c...            1583
# 6423    append basically used python add one element e...            1581
# 14195   code ints index value ints index print index v...            1512
# 27453   pas reference nothing fit well python rarely u...            1460
# 5871    many people use return rather yield case yield...            5524
# 1933       use check file certain directory import o code            2729
# 1934    adding one slight variation not exactly reflec...            2729
# 1915    want bash would file prog file fi sometimes us...            2729
# 39822   put simply used show string representation obj...            1363
# 39819   print decimal print called result raw number p...            1363
# 2310    one option seems pyqtdeploy citing doc tool co...            1360
# 10429                  yes b true else false print b true            2655
# 28610   add new key dictionary way example dictionary ...            1201
# 2061    research following code work well basically pr...            2312
# 2065    simple way use o module import o alternatively...            2312
# 644     following java like enum implementation propos...            1146
# 659                 like use list set enumeration example            1146
# 639     use following type used django model choice lo...            1146
# 648     like java enum python def enum clsdef class en...            1146
# 647     def enum name make enum usage e enum print cla...            1146
# 661     python implementation chosen idea helper metho...            1146
# 657     use metaclass implement enumeration thought co...            1146
# 7435    ended felt cleanest formatters print currently...            1024
# 1604    regard answer constant static variable use des...            1015
# 1602    best way found use another class create object...            1015
#
#         Score_answer  Score_ratio
# 5872               1       5524.0
# 1929               1       2729.0
# 1931               1       2729.0
# 2062               1       2312.0
# 2073               1       2312.0
# 2071               1       2312.0
# 2068               1       2312.0
# 20290              1       1920.0
# 20294              1       1920.0
# 760                1       1867.0
# 762                1       1867.0
# 768                1       1867.0
# 770                1       1867.0
# 771                1       1867.0
# 756                1       1867.0
# 752                1       1867.0
# 16757              1       1837.0
# 16740              1       1837.0
# 131148             1       1662.0
# 131147             1       1662.0
# 131143             1       1662.0
# 131140             1       1662.0
# 131137             1       1662.0
# 131133             1       1662.0
# 131139             1       1662.0
# 3390               1       1583.0
# 6423               1       1581.0
# 14195              1       1512.0
# 27453              1       1460.0
# 5871               4       1381.0
# 1933               2       1364.5
# 1934               2       1364.5
# 1915               2       1364.5
# 39822              1       1363.0
# 39819              1       1363.0
# 2310               1       1360.0
# 10429              2       1327.5
# 28610              1       1201.0
# 2061               2       1156.0
# 2065               2       1156.0
# 644                1       1146.0
# 659                1       1146.0
# 639                1       1146.0
# 648                1       1146.0
# 647                1       1146.0
# 661                1       1146.0
# 657                1       1146.0
# 7435               1       1024.0
# 1604               1       1015.0
# 1602               1       1015.0

# %%
plt.figure(figsize=(12,8))
plt.hist(df["Score_ratio"], bins=5000, edgecolor='black')
plt.xlim(-50,50)
plt.title("Question vs Answer Scores")
plt.title("Distribution of Score Ratios (Question / Answer)")
plt.xlabel("Score Ratio")
plt.ylabel("Frequency")
plt.show()

# %%
def bin_count(a: int, b: int):
    bin_counts = (df["Score_ratio"] >= a) & (df["Score_ratio"] < b)
    count = bin_counts.sum()
    return count

# %%
print(bin_count(-1,1))
# Out:
# 350516

# %%
plt.figure(figsize=(12,8))
plt.hist(df["Score_ratio"], bins=5000, edgecolor='black')
plt.xlim(-10,10)
plt.title("Question vs Answer Scores")
plt.title("Distribution of Score Ratios (Question / Answer)")
plt.xlabel("Score Ratio")
plt.ylabel("Frequency")
plt.show()

# %%
df_good_subset = df[(df["Score_ratio"] >= 0) & (df["Score_ratio"] <= 1)]

# %%
df_sorted_good_subset = df_good_subset.sort_values(by="Score_question", ascending=True)

# %%
df_sorted_good_subset.head(50)
# Out:
#               Id                                                Tag  \
# 947256  38697037         ['python', 'python-3.x', 'python-unicode']
# 300042  12344414  ['c++', 'python', 'performance', 'code-generat...
# 721809  30457198                        ['python', 'math', 'floor']
# 179191   6832332                               ['python', 'syntax']
# 400313  17011074                                         ['python']
# 339303  14166358      ['python', 'string', 'comparison', 'element']
# 784009  32799607                                         ['python']
# 723824  30537791                       ['python', 'list', 'tuples']
# 666985  28391831                                         ['python']
# 432707  18433341                               ['python', 'django']
# 56505    1999144                                         ['python']
# 276468  11297980                  ['python', 'linux', 'batch-file']
# 339238  14162278                   ['python', 'regex', 'substring']
# 460237  19632180                                         ['python']
# 655527  27943030                                         ['python']
# 421942  17944249       ['python', 'list', 'multidimensional-array']
# 363662  15322130             ['python', 'square-root', 'math.sqrt']
# 537261  22865572                         ['python', 'if-statement']
# 439379  18738027     ['python', 'json', 'url', 'python-3.x', 'get']
# 745378  31344416                                         ['python']
# 387448  16430798                 ['python', 'syntax', 'python-2.7']
# 23666     858109            ['python', 'list', 'find', 'iteration']
# 232235   9323739                                         ['python']
# 464438  19795307                                         ['python']
# 871097  35894613                                         ['python']
# 785277  32849225                   ['python', 'list', 'python-2.7']
# 726848  30654159                                         ['python']
# 43193    1550406                                         ['python']
# 909735  37293602  ['python', 'string', 'performance', 'padding',...
# 266460  10867290                                ['python', 'split']
# 889120  36544824         ['python', 'list', 'tuples', 'python-3.5']
# 291068  11929274                                 ['python', 'ipv6']
# 814386  33883418                                         ['python']
# 667423  28405899     ['python', 'sockets', 'python-2.7', 'ioerror']
# 43192    1550406                                         ['python']
# 966590  39402495                                ['python', 'regex']
# 462162  19712518                               ['python', 'opengl']
# 658303  28050616                           ['python', 'dictionary']
# 565358  24120455  ['python', 'list', 'python-2.7', 'list-compreh...
# 464420  19794675                   ['c#', 'python', 'math', 'hlsl']
# 568060  24242941                                 ['python', 'list']
# 783953  32797645                       ['python', 'string', 'list']
# 707081  29918652                                         ['python']
# 391677  16620607                              ['python', 'unicode']
# 391678  16620607                              ['python', 'unicode']
# 651767  27779964                       ['python', 'numpy', 'scipy']
# 783915  32796139                    ['python', 'bitwise-operators']
# 464419  19794675                   ['c#', 'python', 'math', 'hlsl']
# 543666  23128318                                 ['python', 'list']
# 305973  12625636                                         ['python']
#
#         Score_question                                              Title  \
# 947256             -10  convert python unicode function correct python...
# 300042             -10                          use code converter python
# 721809              -9  floor function not symmetric positive negative...
# 179191              -7                                python syntax error
# 400313              -7                             check something python
# 339303              -7                                  string comparison
# 784009              -7                                        create loop
# 723824              -7                          python defining list list
# 666985              -6   xxpython comment multiple line not working array
# 432707              -6           custom django login not compare password
# 56505               -6           calling variable another function python
# 276468              -6                      run python script batch linux
# 339238              -6          need extract substring based regex python
# 460237              -6     error not argument converted string formatting
# 655527              -6                                    function python
# 421942              -6  make list item sublist multidimensional list p...
# 363662              -6                          square root number python
# 537261              -6  best practice include else pas statement end p...
# 439379              -6                                python get json url
# 745378              -6        python keep reporting syntax erro statement
# 387448              -6                   invalid syntax error python code
# 23666               -6                     list element without iteration
# 232235              -6  python unfair treating list non list variable ...
# 464438              -6                 merging list key value pair python
# 871097              -6                      disallow access file one user
# 785277              -6               printing list show single quote mark
# 726848              -6                            python join list string
# 43193               -5              download htmlsource webpage make line
# 909735              -5  efficiency pythonicity padding space string py...
# 266460              -5          python string split many piece many piece
# 889120              -5                 getting integer list tuples python
# 291068              -5                        display client ip name like
# 814386              -5                                    not snippet add
# 667423              -5          python io error time attempting open file
# 43192               -5              download htmlsource webpage make line
# 966590              -5                                         regex mean
# 462162              -5                               python code wont run
# 658303              -5                  alphabetically sorting dictionary
# 565358              -5                              increment list python
# 464420              -5                                                map
# 568060              -5                                               list
# 783953              -5                       turn list complicated string
# 707081              -5                            convert list set python
# 391677              -5  python unicode handling error simply remove un...
# 391678              -5  python unicode handling error simply remove un...
# 651767              -5                                        kind number
# 783915              -5                                    operator versus
# 464419              -5                                                map
# 543666              -5                   get list pair word length python
# 305973              -5            python string function strip last comma
#
#                                             Body_question  Score_answer  \
# 947256  enabled compatibility check python ide realize...            10
# 300042  let say right bat not programmer guy idea taki...            12
# 721809  using python function giving different answer ...            11
# 179191  try run code def table nb nb print nb nb else ...            10
# 400313  wrote could please see wrong code beginner pyt...             7
# 339303  need fast function comparison two string examp...            12
# 784009  currently use range print print digit want add...             9
# 723824  trying define table color contains various tab...             8
# 666985  example array want comment work array not arra...             6
# 432707  new django python read doc standard login syst...             7
# 56505   trying call variable use another function vari...             7
# 276468  please let know way run multiple python script...             8
# 339238  need extract substring come possible combinati...             7
# 460237  name name quest quest color favorite color pri...             7
# 655527  new python playing problem function according ...             6
# 421942  question following list would like get list se...             6
# 363662  code import cmath root print root problem face...             6
# 537261  write b something elif c something else want p...             6
# 439379  hello fellow programmer today wanted get json ...             9
# 745378  beginner programmer currently learning python ...             6
# 387448  keep getting invalid syntax notification aroun...             6
# 23666       want know find element list without iteration             9
# 232235  example code mat x def add c b print x c b add...             9
# 464438  input model color brand value red output color...             6
# 871097  trying disable user opening file purpose user ...             6
# 785277  following python code snippet range print outp...            11
# 726848  seems easy getting error not know get rid coun...             7
# 43193   urlreq theurl agent urlresponse urlreq htmlsou...             6
# 909735  fill python string space accepted answer pad c...             6
# 266460  split long string separated semicolon want kno...             6
# 889120  list tuples like b c would like extract list l...             5
# 291068  hi sorry disturbing guy read something magazin...             8
# 814386  nb nb nb nb inferior print nb nb print add nb ...             5
# 667423  command line aaron get def main argv servernam...            11
# 43192   urlreq theurl agent urlresponse urlreq htmlsou...             9
# 966590  starting learn python spider download picture ...             5
# 462162  python code wont run not know solve problem an...             8
# 658303  researched bit around however tried implementi...             5
# 565358  reading csv file return getting set url saved ...             6
# 464420  trying convert value without using statement t...             7
# 568060                          way transform h e l l w r             5
# 783953         want turn list string preferrably one line             5
# 707081  expecting mylist set mylist produce instead pr...             7
# 391677  literally dozen maybe even hundred question si...             7
# 391678  literally dozen maybe even hundred question si...             8
# 651767  declared x variable filled print x method give...             5
# 783915  difference two not implemented use think may c...             5
# 464419  trying convert value without using statement t...             9
# 543666  list item beef pork ham need return list word ...             7
# 305973  input str ouput str requirement strip last occ...            11
#
#                                               Body_answer  Score_ratio
# 947256  already pointed comment already advice porting...     1.000000
# 300042  generally awful way write code not guarantee f...     0.833333
# 721809  per documentation return floor x float largest...     0.818182
# 179191  suspect trying print nb nb note comma final ar...     0.700000
# 400313  want test equality string exit not convert int...     1.000000
# 339303  zero effort shown heck weekend itertools impor...     0.583333
# 784009  rather create range loop string get individual...     0.777778
# 723824  list not take pair probably want dictionary in...     0.875000
# 666985  using multi line string syntax not commenting ...     1.000000
# 432707  not django perfectly good fully documented sys...     0.857143
# 56505   guessing vague question result another functio...     0.857143
# 276468  create script file called python python make s...     0.750000
# 339238                               following r p string     0.857143
# 460237  typo order string formatting occur thus three ...     0.857143
# 655527  list return boolean value based content list t...     1.000000
# 421942                   using list comprehension l x z l     1.000000
# 363662  use math module instead cmath module latter co...     1.000000
# 537261  no not else suite entirely optional statement ...     1.000000
# 439379  site trying fetch not available seen http coul...     0.666667
# 745378  elif come immediately block elif block string ...     1.000000
# 387448  room check lab look around lab find nothing im...     1.000000
# 23666   blah method list return index first occurrence...     0.666667
# 232235  not think variable python named box store data...     0.666667
# 464438  make dictionary store pair dict zip need strin...     1.000000
# 871097  unix permission primer every file user user sy...     1.000000
# 785277  printing repr format list use join format inst...     0.545455
# 726848  conversion integer value string using str counter     0.857143
# 43193   one line function like def getsource url urlre...     0.833333
# 909735  purpose function not add fixed number char sta...     0.833333
# 266460  could get length list item splitting len alter...     0.833333
# 889120  goal efficiency let u look different method ti...     1.000000
# 291068  address localhost like address localhost seein...     0.625000
# 814386  python us indent block initial program not inc...     1.000000
# 667423  might noticed trying strip beginning url thoug...     0.454545
# 43192   not really possible thing put response source ...     0.555556
# 966590  alright answer first question break square bra...     1.000000
# 462162  two line problem numpy created list object bou...     0.625000
# 658303  sorted v sort string alphabetically returning ...     1.000000
# 565358  think pythonic way clear not would url url com...     0.833333
# 464420  would give value strong chance not want really...     0.714286
# 568060                                          word word     1.000000
# 783953  using string formatting list comprehension inp...     1.000000
# 707081                        mean tuple try tuple mylist     0.714286
# 391677  problem not go away code not handle unicodes p...     0.714286
# 391678  decode ascii everything ignoring error however...     0.625000
# 651767  number already floating point number written s...     1.000000
# 783915  course difference print print one addition bit...     1.000000
# 464419                            python arr mapped arr n     0.555556
# 543666  len item example item beef pork ham len item p...     0.714286
# 305973                                  use rstrip result     0.454545

# %%
df_sorted_good_subset.describe()
# Out:
#                  Id  Score_question   Score_answer    Score_ratio
# count  4.650500e+05   465050.000000  465050.000000  465050.000000
# mean   2.107375e+07        2.313448       4.626823       0.436521
# std    1.143106e+07       19.553445      28.217718       0.406437
# min    5.940000e+02      -10.000000      -7.000000      -0.000000
# 25%    1.138445e+07        0.000000       1.000000       0.000000
# 50%    2.151633e+07        1.000000       2.000000       0.400000
# 75%    3.099757e+07        2.000000       4.000000       1.000000
# max    4.014319e+07     5524.000000    8384.000000       1.000000

# %% [markdown]
# The score ratio represents the ratio of the ratio of the question score to the answer score. Ranking answers by their score ratio is the next step, based on the assumption that if a given question has a certain number of upvotes, then good answers to the given question will also have a similar number of upvotes. Based on this assumption, the "best answers" to a given question should have a score ratio between 0 and 1, with questions having higher score ratios than that being worse responses. This is reflected in the graphs above.

# %% [markdown]
# # Implementing Heuristic Function

# %% [markdown]
# Here we create an interval search function, taking the score_ratio (between question score and answer score) and ranking questions based on a certain upper bound and lower bound for the score ratio, and lowest overall question score.

# %%
def Interval_Search(lower_bound, upper_bound, lowest_question_score):
    return df[(df["Score_ratio"] >= lower_bound) & (df["Score_ratio"] <= upper_bound) & (df["Score_question"] > lowest_question_score)].sort_values(by="Score_answer", ascending=False)

# %%
Interval_Search(0,1,50)
# Out:
#               Id                                                Tag  \
# 5845      231767  ['python', 'iterator', 'generator', 'yield', '...
# 2233      100003  ['python', 'oop', 'metaclass', 'python-datamod...
# 20287     739654       ['python', 'decorator', 'python-decorators']
# 10416     394809  ['python', 'operators', 'ternary-operator', 'c...
# 14187     522563                        ['python', 'loops', 'list']
# ...          ...                                                ...
# 379662  16082954                      ['python', 'list', 'sorting']
# 77757    2731022  ['python', 'comments', 'interpreter', 'interpr...
# 394016  16729574         ['python', 'table', 'dataframe', 'pandas']
# 112579   4019971                                         ['python']
# 369624  15607903         ['python', 'file', 'permissions', 'chmod']
#
#         Score_question                                        Title  \
# 5845              5524                                yield keyword
# 2233              3219                             metaclass python
# 20287             1920         make chain function decorator python
# 10416             2655          python ternary conditional operator
# 14187             1512                  accessing index python loop
# ...                ...                                          ...
# 379662              52    python sort list dictionary several value
# 77757               51            comment slow interpreted language
# 394016              51                    get value cell data frame
# 112579              52       implement self container object python
# 369624              51  python module file not change permission wx
#
#                                             Body_question  Score_answer  \
# 5845    use yield keyword python example trying unders...          8384
# 2233                                      metaclasses use          4510
# 20287   make two decorator python would following make...          3332
# 10416   python not ternary conditional operator possib...          3110
# 14187   access index list like following ints loop usi...          2666
# ...                                                   ...           ...
# 379662  want sort list first value second value easy w...            52
# 77757   asking use python could apply interpreted lang...            52
# 394016  constructed condition extract exactly one row ...            52
# 112579  written custom container object according page...            52
# 369624  recently using python module o tried change pe...            51
#
#                                               Body_answer  Score_ratio
# 5845    understand yield must understand generator gen...     0.658874
# 2233    class object understanding metaclasses need ma...     0.713747
# 20287   not long explanation see paolo answer decorato...     0.576230
# 10416   yes added version syntax condition else b firs...     0.853698
# 14187   using additional state variable index variable...     0.567142
# ...                                                   ...          ...
# 379662                  operator import itemgetter sorted     1.000000
# 77757   case python source file compiled executed file...     0.980769
# 394016  dataframe one row access first row series usin...     0.980769
# 112579  normally would use generator function time use...     1.000000
# 369624  found different forum wondering leading zero i...     1.000000
#
# [2206 rows x 8 columns]

# %%
Interval_Search(0,3,50)
# Out:
#               Id                                                Tag  \
# 5845      231767  ['python', 'iterator', 'generator', 'yield', '...
# 2233      100003  ['python', 'oop', 'metaclass', 'python-datamod...
# 20287     739654       ['python', 'decorator', 'python-decorators']
# 10416     394809  ['python', 'operators', 'ternary-operator', 'c...
# 14187     522563                        ['python', 'loops', 'list']
# ...          ...                                                ...
# 437146  18641438          ['python', 'python-3.x', 'cygwin', 'pip']
# 52041    1859072                                ['python', 'loops']
# 298227  12253200  ['python', 'functional-programming', 'lisp', '...
# 938282  38369470                               ['python', 'lambda']
# 102309   3639574                     ['python', 'regex', 'parsing']
#
#         Score_question                                              Title  \
# 5845              5524                                      yield keyword
# 2233              3219                                   metaclass python
# 20287             1920               make chain function decorator python
# 10416             2655                python ternary conditional operator
# 14187             1512                        accessing index python loop
# ...                ...                                                ...
# 437146              52                                  installing cygwin
# 52041               52        python continuing next iteration outer loop
# 298227              51                         lisp loop different python
# 938282              51  lambda list comprehension returning lambda called
# 102309              51                  writing parser regular expression
#
#                                             Body_question  Score_answer  \
# 5845    use yield keyword python example trying unders...          8384
# 2233                                      metaclasses use          4510
# 20287   make two decorator python would following make...          3332
# 10416   python not ternary conditional operator possib...          3110
# 14187   access index list like following ints loop usi...          2666
# ...                                                   ...           ...
# 437146  python installed cygwin however unable install...            18
# 52041   wanted know way continue next iteration outer ...            18
# 298227  encounter following statement richard stallman...            17
# 938282  trying iterate lambda func list want get call ...            17
# 102309  even year programming ashamed say never really...            17
#
#                                               Body_answer  Score_ratio
# 5845    understand yield must understand generator gen...     0.658874
# 2233    class object understanding metaclasses need ma...     0.713747
# 20287   not long explanation see paolo answer decorato...     0.576230
# 10416   yes added version syntax condition else b firs...     0.853698
# 14187   using additional state variable index variable...     0.567142
# ...                                                   ...          ...
# 437146  think alternative install instruction linked m...     2.888889
# 52041   language label loop break labelled loop python...     2.888889
# 298227  system one typically develops program running ...     3.000000
# 938282  closure python meaning lambda function list ev...     3.000000
# 102309  already given mark byers far remember paper no...     3.000000
#
# [4484 rows x 8 columns]

# %%
def plotting_searched_df(lower_bound, upper_bound, lowest_question_score):
    Searched_df = Interval_Search(lower_bound,upper_bound,lowest_question_score)
    plt.figure(figsize=(12,8))
    plt.scatter(Searched_df["Score_question"], Searched_df["Score_answer"], alpha=0.6)
    plt.xlabel("Question Score")
    plt.ylabel("Answer Score")
    plt.title("Question vs Answer Scores in Searched Data Frame")

    plt.figure(figsize=(12,8))
    plt.scatter(Searched_df["Score_ratio"], Searched_df["Score_question"], alpha=0.6)
    plt.xlabel("Ratio")
    plt.ylabel("Question Score")
    plt.title("Question vs Answer Scores in Searched Data Frame")

    return Searched_df

# %%
plotting_searched_df(0, 1, 50)
# Out:
#               Id                                                Tag  \
# 5845      231767  ['python', 'iterator', 'generator', 'yield', '...
# 2233      100003  ['python', 'oop', 'metaclass', 'python-datamod...
# 20287     739654       ['python', 'decorator', 'python-decorators']
# 10416     394809  ['python', 'operators', 'ternary-operator', 'c...
# 14187     522563                        ['python', 'loops', 'list']
# ...          ...                                                ...
# 379662  16082954                      ['python', 'list', 'sorting']
# 77757    2731022  ['python', 'comments', 'interpreter', 'interpr...
# 394016  16729574         ['python', 'table', 'dataframe', 'pandas']
# 112579   4019971                                         ['python']
# 369624  15607903         ['python', 'file', 'permissions', 'chmod']
#
#         Score_question                                        Title  \
# 5845              5524                                yield keyword
# 2233              3219                             metaclass python
# 20287             1920         make chain function decorator python
# 10416             2655          python ternary conditional operator
# 14187             1512                  accessing index python loop
# ...                ...                                          ...
# 379662              52    python sort list dictionary several value
# 77757               51            comment slow interpreted language
# 394016              51                    get value cell data frame
# 112579              52       implement self container object python
# 369624              51  python module file not change permission wx
#
#                                             Body_question  Score_answer  \
# 5845    use yield keyword python example trying unders...          8384
# 2233                                      metaclasses use          4510
# 20287   make two decorator python would following make...          3332
# 10416   python not ternary conditional operator possib...          3110
# 14187   access index list like following ints loop usi...          2666
# ...                                                   ...           ...
# 379662  want sort list first value second value easy w...            52
# 77757   asking use python could apply interpreted lang...            52
# 394016  constructed condition extract exactly one row ...            52
# 112579  written custom container object according page...            52
# 369624  recently using python module o tried change pe...            51
#
#                                               Body_answer  Score_ratio
# 5845    understand yield must understand generator gen...     0.658874
# 2233    class object understanding metaclasses need ma...     0.713747
# 20287   not long explanation see paolo answer decorato...     0.576230
# 10416   yes added version syntax condition else b firs...     0.853698
# 14187   using additional state variable index variable...     0.567142
# ...                                                   ...          ...
# 379662                  operator import itemgetter sorted     1.000000
# 77757   case python source file compiled executed file...     0.980769
# 394016  dataframe one row access first row series usin...     0.980769
# 112579  normally would use generator function time use...     1.000000
# 369624  found different forum wondering leading zero i...     1.000000
#
# [2206 rows x 8 columns]

# %% [markdown]
# This is an implementation of the "radial/sector search" based on score ratios. The values we want to consider fall into a certain section. Since the upper bound is already decided by the data we have provided, all I've done here is filtered the data based on "goodness" (number of upvotes) relative to the number of upvotes the question had. Then I've graphed this (both in a question_score, answer_score format and in a ratio to question_score format) to better visualize the data. The second search function also returns the respective rows that are graphed. For a better look at what this does, see the original graph.
